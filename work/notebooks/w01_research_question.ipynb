# %% [markdown]
# <a href="https://colab.research.google.com/github/palkinsuneja/palkin-flyrank-ml-internship-july-to-sept-2026/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/palkinsuneja/palkin-flyrank-ml-internship-july-to-sept-2026/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# The goal of this project is to identify webpages that should be reviewed first for content refresh. Since editorial resources are limited, not every page can be updated at the same time. I want to prioritize pages using observable search and content signals such as impressions, clicks, CTR, engagement, and content freshness. This project will help rank pages based on their potential impact so editors can focus on the most valuable opportunities first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
lane = "Refresh / Content Opportunity Scoring"

keywords = [
    "impressions",
    "clicks",
    "CTR",
    "engagement",
    "freshness"
]

print("Selected Lane:", lane)
print("Signals to analyze:")
for k in keywords:
    print("-", k)
# Out:
# Selected Lane: Refresh / Content Opportunity Scoring
# Signals to analyze:
# - impressions
# - clicks
# - CTR
# - engagement
# - freshness

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This project helps decide which webpages should be reviewed first for content improvement.
#
# The primary users are content editors and SEO teams. Based on the ranking produced by the model, they can decide which pages to refresh, expand, or monitor.
#
# A wrong recommendation may waste editorial time by prioritizing pages that do not actually need attention. It may also cause important pages with real opportunities to be ignored, leading to missed traffic and engagement improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
decision = {
    "Decision": "Prioritize pages for content refresh",
    "Users": "SEO Team and Content Editors",
    "Wrong Call": "Wasted effort and missed opportunities"
}

for key, value in decision.items():
    print(f"{key}: {value}")
# Out:
# Decision: Prioritize pages for content refresh
# Users: SEO Team and Content Editors
# Wrong Call: Wasted effort and missed opportunities

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os

print(os.getcwd())
# !pwd
# !ls -la
# Out:
# /content/palkin-flyrank-ml-internship-july-to-sept-2026
# /content/palkin-flyrank-ml-internship-july-to-sept-2026
# total 104
# drwxr-xr-x 12 root root  4096 Aug  1 18:35 .
# drwxr-xr-x  1 root root  4096 Aug  1 18:35 ..
# -rw-r--r--  1 root root   654 Aug  1 18:35 AGENTS.md
# -rw-r--r--  1 root root   654 Aug  1 18:35 CLAUDE.md
# drwxr-xr-x  3 root root  4096 Aug  1 18:35 data
# -rw-r--r--  1 root root  2763 Aug  1 18:35 DATA_USE.md
# drwxr-xr-x  2 root root  4096 Aug  1 18:35 docs
# drwxr-xr-x  8 root root  4096 Aug  1 18:35 .git
# drwxr-xr-x  3 root root  4096 Aug  1 18:35 .github
# -rw-r--r--  1 root root   993 Aug  1 18:35 .gitignore
# -rw-r--r--  1 root root 10408 Aug  1 18:35 GUIDE.md
# -rw-r--r--  1 root root  1289 Aug  1 18:35 LICENSE
# drwxr-xr-x  2 root root  4096 Aug  1 18:35 notebooks
# drwxr-xr-x  3 root root  4096 Aug  1 18:35 outputs
# -rw-r--r--  1 root root 10120 Aug  1 18:35 README.md
# -rw-r--r--  1 root root   107 Aug  1 18:35 requirements.txt
# ...

# %%
# !git clone https://github.com/palkinsuneja/palkin-flyrank-ml-internship-july-to-sept-2026.git
# Out:
# Cloning into 'palkin-flyrank-ml-internship-july-to-sept-2026'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 124 (delta 39), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.85 MiB | 7.47 MiB/s, done.
# Resolving deltas: 100% (39/39), done.

# %%
import os

os.chdir("/content/palkin-flyrank-ml-internship-july-to-sept-2026")
print("Current Directory:", os.getcwd())
# Out:
# Current Directory: /content/palkin-flyrank-ml-internship-july-to-sept-2026

# %%
import os

print("Current:", os.getcwd())
print("Exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
print("Files:", os.listdir("data/raw"))
# Out:
# Current: /content/palkin-flyrank-ml-internship-july-to-sept-2026
# Exists: True
# Files: ['content_refresh_anonymized.csv']

# %% [markdown]
# The starter dataset contains around **30,000 anonymized content records**.
#
# According to the internship guide, the starter experiments showed:
#
# - Baseline Precision@50 = **0.24**
# - Decision Tree Precision@50 = **0.54**
# - Random Forest Precision@50 = **0.74**
#
# These numbers show that a machine learning model can rank content opportunities better than simple rule-based scoring on the starter dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))

print("\nFirst 5 columns:")
print(df.columns[:5].tolist())

print("\nNumeric summary:")
display(df.describe())
# Out:
# Rows: 30000
# Columns: 44
#
# First 5 columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level']
#
# Numeric summary:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project provides decision support for identifying pages that may deserve content review based on observable search and engagement signals.
#
# The results are observational and evidence-based. They do not prove that refreshing a page will definitely improve its performance.
#
# I will avoid making causal claims about Google's algorithm or saying that the model guarantees future success. Human review is still required before taking any action.

# %%
claims = {
    "Can Claim": [
        "Observed search patterns",
        "Decision-support ranking",
        "Evidence-based recommendations"
    ],
    "Cannot Claim": [
        "Google ranking algorithm",
        "Guaranteed traffic increase",
        "Causal proof"
    ]
}

for key, value in claims.items():
    print(f"{key}:")
    for item in value:
        print("-", item)
    print()
# Out:
# Can Claim:
# - Observed search patterns
# - Decision-support ranking
# - Evidence-based recommendations
#
# Cannot Claim:
# - Google ranking algorithm
# - Guaranteed traffic increase
# - Causal proof

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
